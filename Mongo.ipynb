# %%
import pandas as pd
from pymongo import MongoClient


def _connect_mongo(host, port, username, password, db):
    """ A util for making a connection to mongo """

    if username and password:
        mongo_uri = 'mongodb://%s:%s@%s:%s/%s' % (username, password, host, port, db)
        conn = MongoClient(mongo_uri)
    else:
        conn = MongoClient(host, port)


    return conn[db]

# %%
def read_mongo(db, collection, query={}, host='localhost', port=27017, username=None, password=None, no_id=True):
    """ Read from Mongo and Store into DataFrame """

    # Connect to MongoDB
    db = _connect_mongo(host=host, port=port, username=username, password=password, db=db)

    # Make a query to the specific DB and Collection
    cursor = db[collection].find(query)

    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor))

    # Delete the _id
    if no_id:
        del df['_id']

    return df

# %%
df = read_mongo(db="propertiesdb", collection="apartment", host='192.168.0.17')

# %%
df['point'] = df['address'].apply(lambda v: v.get('point') if isinstance(v, dict) else '')
df['link_url'] = df['link'].apply(lambda v: v.get('href') if isinstance(v, dict) else '')
df['point']
# Out:
# 0       {'lon': -47.049274, 'source': 'GOOGLE', 'lat':...
# 1       {'lon': -47.049899, 'source': 'GOOGLE', 'lat':...
# 2       {'lon': -47.049899, 'source': 'GOOGLE', 'lat':...
# 3       {'lon': -47.04951, 'source': 'GOOGLE', 'lat': ...
# 4       {'lon': -47.049274, 'source': 'GOOGLE', 'lat':...
#                               ...
# 5052    {'lon': -47.053892, 'source': 'GOOGLE', 'lat':...
# 5053    {'lon': -47.050091, 'source': 'GOOGLE', 'lat':...
# 5054    {'lon': -47.079115, 'source': 'GOOGLE', 'lat':...
# 5055    {'lon': -47.059443, 'source': 'GOOGLE', 'lat':...
# 5056    {'lon': -47.049693, 'source': 'GOOGLE', 'lat':...
# Name: point, Length: 5057, dtype: object

# %%
df['lon'] = pd.to_numeric(df['point'].apply(lambda v: v.get('lon') if isinstance(v, dict) else ''), errors='coerce')
df['lat'] = pd.to_numeric(df['point'].apply(lambda v: v.get('lat') if isinstance(v, dict) else ''), errors='coerce')

df['lat']
# Out:
# 0      -22.942955
# 1      -22.944549
# 2      -22.944549
# 3      -22.942379
# 4      -22.942955
#           ...
# 5052   -22.882355
# 5053   -22.939591
# 5054   -22.893305
# 5055   -22.893871
# 5056   -22.852896
# Name: lat, Length: 5057, dtype: float64

# %%
import numpy as np
def haversine_np(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    

    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

# %%
lat_default, log_default = (-22.9388, -47.050991)
haversine_np(lat_default, log_default, -22.9388, -47.050991)
# Out:
# 0.0

# %%
df['dist'] = \
    haversine_np(lat_default, log_default, df['lat'], df['lon'])

df[['dist', "title", "lon", "lat"]].sort_values('dist')
# Out:
#              dist                                              title  \
# 525      0.000000  Apartamento residencial à venda, Parque Prado,...
# 460      0.000000  Apartamento residencial à venda, Parque Prado,...
# 3860     0.000000  APARTAMENTO RESIDENCIAL em CAMPINAS - SP, PARQ...
# 581      0.000000         Lindo Apartamento Cond Caapuã Parque Prado
# 571      0.000000  Apartamento com 3 dormitórios à venda, 92 m² p...
# ...           ...                                                ...
# 3164  3435.257424  Otimo apartamento térreo com Garden 3 dormitór...
# 1351  3436.673589  Apartamento com 3 dorms, 1 Suíte, 2 vagas, 103...
# 1497  3442.204807  Apartamento no Mansões Santo Antonio com 73 me...
# 3449          NaN               Lindo apartamento oportunidade única
# 4977          NaN  Lindo apartamento 2 dormitórios sendo uma suít...
#
#             lon        lat
# 525  -47.050991 -22.938800
# 460  -47.050991 -22.938800
# 3860 -47.050991 -22.938800
# 581  -47.050991 -22.938800
# 571  -47.050991 -22.938800
# ...         ...        ...
# 3164 -22.937527 -47.061014
# 1351 -22.938844 -47.088752
# 1497 -22.853068 -47.043980
# 3449        NaN        NaN
# 4977        NaN        NaN
#
# [5057 rows x 4 columns]

# %%
df2 = df[(df.dist == 0 )]
df1 = df[(df.id_vivareal == '2462027022')]
df2
#link__href
#df2[['dist', "title", "link_url", "price", "totalAreas"]].to_csv('output.csv', encoding='utf-8', index=False)
# Out:
#      displayAddressType                                          amenities  \
# 106        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, GOU...
# 107        NEIGHBORHOOD  [BARBECUE_GRILL, ELEVATOR, GOURMET_BALCONY, POOL]
# 197        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, GATED_COMMU...
# 261        NEIGHBORHOOD  [BARBECUE_GRILL, POOL, GOURMET_SPACE, FURNISHE...
# 303        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, GATED_COMMU...
# 309        NEIGHBORHOOD  [BARBECUE_GRILL, POOL, GOURMET_SPACE, FURNISHE...
# 324        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, ELE...
# 330        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, ELE...
# 333        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, ELE...
# 334        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, GATED_COMMU...
# 335        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, KITCHEN, EL...
# 352        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, ELE...
# 394        NEIGHBORHOOD  [BARBECUE_GRILL, KITCHEN, ELEVATOR, GOURMET_BA...
# 407        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, GATED_COMMU...
# 410        NEIGHBORHOOD  [BARBECUE_GRILL, KITCHEN, ELEVATOR, GOURMET_BA...
# 422                 ALL  [PLAYGROUND, BARBECUE_GRILL, ELEVATOR, GARAGE,...
# 434        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, ELE...
# 441        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, GATED_COMMU...
# 448        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, ELE...
# 456        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, ELE...
# 460        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, ELE...
# 512        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, KITCHEN, EL...
# 513        NEIGHBORHOOD  [BARBECUE_GRILL, KITCHEN, ELEVATOR, GOURMET_BA...
# 514        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, ELE...
# 515        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, GATED_COMMU...
# 516        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, GATED_COMMU...
# 524        NEIGHBORHOOD  [BARBECUE_GRILL, KITCHEN, ELEVATOR, GOURMET_BA...
# 525        NEIGHBORHOOD  [BARBECUE_GRILL, KITCHEN, ELEVATOR, GOURMET_BA...
# 570        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, ELE...
# 571        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, GATED_COMMU...
# 581        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, KITCHEN, EL...
# 611        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, KITCHEN, GO...
# 617        NEIGHBORHOOD  [BARBECUE_GRILL, KITCHEN, ELEVATOR, GOURMET_BA...
# 633        NEIGHBORHOOD  [BARBECUE_GRILL, GATED_COMMUNITY, KITCHEN, ELE...
# 659        NEIGHBORHOOD  [BARBECUE_GRILL, GOURMET_BALCONY, INTERCOM, PO...
# 747                 ALL  [PLAYGROUND, ADULT_POOL, BARBECUE_GRILL, ELEVA...
# 754        NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, GATED_COMMU...
# 3860       NEIGHBORHOOD  [KITCHEN, LAUNDRY, PARTY_HALL, GOURMET_BALCONY...
# 4781       NEIGHBORHOOD  [AIR_CONDITIONING, BARBECUE_GRILL, KITCHEN, EL...
#
#        feedsId contractType usableAreas       constructionStatus  \
# 106     AP5058  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 107     AP3852  REAL_ESTATE        [85]  ConstructionStatus_NONE
# 197     AP3444  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 261    AP00427  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 303     AP0728  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 309    AP00765  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 324     AP7126  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 330     AP8758  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 333     AP8987  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 334     AP4752  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 335     AP4024  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 352     AP3178  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 394     AP1952  REAL_ESTATE        [95]  ConstructionStatus_NONE
# 407     AP3578  REAL_ESTATE        [87]  ConstructionStatus_NONE
# 410     AP3098  REAL_ESTATE       [115]  ConstructionStatus_NONE
# 422   AP018412  REAL_ESTATE        [90]  ConstructionStatus_NONE
# 434     AP1317  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 441     AP0746  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 448     AP0244  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 456     AP5040  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 460     AP0671  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 512     AP0005  REAL_ESTATE        [92]  ConstructionStatus_NONE
# 513     AP5405  REAL_ESTATE        [92]  ConstructionStatus_NONE
# 514     AP7489  REAL_ESTATE        [92]  ConstructionStatus_NONE
# 515     AP6006  REAL_ESTATE        [97]  ConstructionStatus_NONE
# 516     AP9232  REAL_ESTATE        [87]  ConstructionStatus_NONE
# 524     AP0496  REAL_ESTATE        [92]  ConstructionStatus_NONE
# 525     AP0901  REAL_ESTATE        [92]  ConstructionStatus_NONE
# 570     AP5435  REAL_ESTATE        [94]  ConstructionStatus_NONE
# 571     AP9013  REAL_ESTATE        [92]  ConstructionStatus_NONE
# 581     AP0357  REAL_ESTATE        [87]  ConstructionStatus_NONE
# 611     AP0020  REAL_ESTATE        [92]  ConstructionStatus_NONE
# 617     AP5215  REAL_ESTATE        [76]  ConstructionStatus_NONE
# 633     AP4009  REAL_ESTATE        [98]  ConstructionStatus_NONE
# 659     AP0289  REAL_ESTATE        [98]  ConstructionStatus_NONE
# 747   AP020696  REAL_ESTATE       [111]  ConstructionStatus_NONE
# 754     AP7331  REAL_ESTATE        [87]  ConstructionStatus_NONE
# 3860   AP00023  REAL_ESTATE        [75]  ConstructionStatus_NONE
# 4781    AP4362  REAL_ESTATE        [78]  ConstructionStatus_NONE
#
#      videoTourLink listingType  \
# 106                       USED
# 107                       USED
# 197                       USED
# 261                       USED
# 303                       USED
# 309                       USED
# 324                       USED
# 330                       USED
# 333                       USED
# 334                       USED
# 335                       USED
# 352                       USED
# 394                       USED
# 407                       USED
# 410                       USED
# 422                       USED
# 434                       USED
# 441                       USED
# 448                       USED
# 456                       USED
# 460                       USED
# 512                       USED
# 513                       USED
# 514                       USED
# 515                       USED
# 516                       USED
# 524                       USED
# 525                       USED
# 570                       USED
# 571                       USED
# 581                       USED
# 611                       USED
# 617                       USED
# 633                       USED
# 659                       USED
# 747                       USED
# 754                       USED
# 3860                      USED
# 4781                      USED
#
#                                             description  \
# 106   Excelente apartamento com 3 suítes, muito bem ...
# 107   Lindo Apartamento no Parque Prado, rico em arm...
# 197   Lindo apartamento com excelente acabamento com...
# 261   APARTAMENTO para Venda<br>PARQUE PRADO, CAMPIN...
# 303   Edifício Caapuã | apartamento andar alto, lind...
# 309   APARTAMENTO para Venda<br>PARQUE PRADO, CAMPIN...
# 324   Lindo Apartamento no Parque Prado, 3 suítes, l...
# 330   Belíssimo apartamento , vista para área de pre...
# 333   Lindo apartamento 3 suítes, lavabo, sala de es...
# 334   AMPLO APARTAMENTO COM 111 M² DE ÁREA ÚTIL, LOC...
# 335   Lindo apartamento no Parque Prado, em andar in...
# 352   INVESTIDOR - LOCADO - Belíssimo apartamento , ...
# 394   Aceita permuta por apartamento de menor valor....
# 407   Ótimo Apartamento Diferenciado, Sol da Manhã, ...
# 410   Maravilhoso apartamento de 3 dormitórios, send...
# 422   ESTUDA PERMUTA!<br><br>Belíssimo apartamento n...
# 434   Apartamento com 111 m² fica no 15º andar (o pr...
# 441   Lindo apartamento sol da manhã, com linda vist...
# 448   Vende-se apartamento de 111m² andar alto no Pa...
# 456   Lindo apartamento 111 metros , sol da manha, v...
# 460   Parque Prado Torre Marajoara 111m² área útil. ...
# 512   Excelente apartamento no Parque Prado, com móv...
# 513   Parque Prado - APARTAMENTO IMPECÁVEL, ao lado ...
# 514   APARTAMENTO IMPECÁVEL,<br>- 100% mobiliado. Mó...
# 515   APARTAMENTO 97 M² PARQUE PRADO , duas vagas de...
# 516   Aconchegante apartamento na região mais deseja...
# 524   Apartamento para Venda/Parque Prado 92 metros ...
# 525   Apartamento impecável e espaçoso no Parque Pra...
# 570   Lindo apto., desocupado, sol da manhã, tudo em...
# 571   Excelente localização, parede com shopping pra...
# 581   Excelente Apartamento - Cond Caapuã Parque Pra...
# 611   APARTAMENTO SOFISTICADO NO PARQUE PRADO, AO LA...
# 617   Lindo apartamento, 03 dormitórios, sendo um de...
# 633   Lindo apartamento, próximo ao Shopping Prado, ...
# 659   - Preço abaixo de mercado.<br>- Ótimo apartame...
# 747   Maravilhoso apartamento à venda em ótima local...
# 754   PERMUTA COM LOTE | Lindo, todo planejado, livi...
# 3860  APARTAMENTO EM CAMPINAS,REGIÃO DO PARQUE PRADO...
# 4781  Maravilhoso apartamento com layout modificado ...
#
#                                                   title  ...  \
# 106   Apartamento residencial à venda, Parque Prado,...  ...
# 107   Apartamento com 3 dormitórios à venda, 85 m² p...  ...
# 197           Parque Prado l 119m³ l 3 suítes l 2 vagas  ...
# 261   APARTAMENTO RESIDENCIAL em CAMPINAS - SP, PARQ...  ...
# 303   Apartamento residencial à venda, Parque Prado,...  ...
# 309       Caapua, lazer clube ao lado do Shopping Prado  ...
# 324   Apartamento com 3 dormitórios à venda, 111 m² ...  ...
# 330   Apartamento com 3 dormitórios à venda, 111 m² ...  ...
# 333   Apartamento com 3 dormitórios à venda, 111 m² ...  ...
# 334   Apartamento residencial à venda, Parque Prado,...  ...
# 335   Apartamento com 3 dormitórios à venda, 111 m² ...  ...
# 352                    Parque Prado - para Investidores  ...
# 394   Apartamento com 3 dormitórios à venda, 95 m² p...  ...
# 407   Apartamento à venda, 87 m² por R$ 689.901,00 -...  ...
# 410   Apartamento com 3 dormitórios (2 suítes) à ven...  ...
# 422               apartamento - Parque Prado - Campinas  ...
# 434   Apartamento residencial para venda e locação, ...  ...
# 441                                        Parque Prado  ...
# 448   Apartamento residencial à venda, Parque Prado,...  ...
# 456   Apartamento residencial à venda, Parque Prado,...  ...
# 460   Apartamento residencial à venda, Parque Prado,...  ...
# 512                  Excelente Apartamento Parque Prado  ...
# 513   Apartamento com 3 dormitórios à venda, 92 m² p...  ...
# 514   Apartamento com 3 dormitórios à venda, 92 m² p...  ...
# 515   Apartamento residencial à venda, Parque Prado,...  ...
# 516                           Apartamento- Parque Prado  ...
# 524   Apartamento para venda Eco Life/Parque Parado/...  ...
# 525   Apartamento residencial à venda, Parque Prado,...  ...
# 570                  Coisa linda, excelente apartamento  ...
# 571   Apartamento com 3 dormitórios à venda, 92 m² p...  ...
# 581          Lindo Apartamento Cond Caapuã Parque Prado  ...
# 611   Apartamento com 3 dormitórios à venda, 92 m² p...  ...
# 617   Lindo apartamento, 03 dorms, sendo uma suíte e...  ...
# 633   Apartamento residencial à venda, Parque Prado,...  ...
# 659   Apartamento residencial à venda, Parque Prado,...  ...
# 747               apartamento - Parque Prado - Campinas  ...
# 754   Caapuã com vista privilegiada, arejado e charmoso  ...
# 3860  APARTAMENTO RESIDENCIAL em CAMPINAS - SP, PARQ...  ...
# 4781  Apartamento residencial à venda, Parque Prado,...  ...
#
#                similares_updated deliveredAt                     updated  \
# 106   2020-04-04 13:41:09.377763         NaN                         NaN
# 107   2020-04-04 13:42:22.409985         NaN  2020-04-07 18:04:16.112380
# 197   2020-04-03 20:28:16.058294         NaN                         NaN
# 261   2020-04-03 21:24:38.006575         NaN                         NaN
# 303   2020-04-03 21:56:39.716394         NaN                         NaN
# 309   2020-04-03 22:01:20.180746         NaN                         NaN
# 324   2020-04-03 22:11:37.148539         NaN                         NaN
# 330   2020-04-03 22:16:10.394059         NaN                         NaN
# 333   2020-04-03 22:17:56.290702         NaN                         NaN
# 334   2020-04-03 22:19:00.303461         NaN                         NaN
# 335   2020-04-03 22:19:37.271872         NaN                         NaN
# 352   2020-04-03 22:32:32.653515         NaN                         NaN
# 394   2020-04-03 23:10:46.155819         NaN  2020-04-07 18:02:21.296742
# 407   2020-04-03 23:23:01.284900         NaN  2020-04-07 18:04:18.791819
# 410   2020-04-03 23:24:57.926045         NaN  2020-04-07 18:01:34.247008
# 422   2020-04-03 23:34:55.492157         NaN  2020-04-07 18:01:01.201736
# 434   2020-04-03 21:06:38.916366         NaN                         NaN
# 441   2020-04-03 21:37:39.684320         NaN                         NaN
# 448   2020-04-03 22:23:08.641151         NaN                         NaN
# 456   2020-04-03 22:52:05.990741         NaN  2020-04-07 18:04:19.577428
# 460   2020-04-03 23:24:09.269671         NaN  2020-04-07 18:05:04.536509
# 512   2020-04-03 23:56:50.680304         NaN  2020-04-07 18:01:25.887319
# 513   2020-04-03 23:57:34.109923         NaN  2020-04-07 18:02:52.224385
# 514   2020-04-03 23:59:46.018343         NaN  2020-04-07 18:04:33.288215
# 515   2020-04-04 00:00:29.667510         NaN  2020-04-07 18:03:38.593027
# 516   2020-04-04 00:01:11.707215         NaN  2020-04-07 18:04:07.413838
# 524   2020-04-04 00:07:59.900684         NaN  2020-04-07 18:02:02.039899
# 525   2020-04-04 00:08:32.695670         NaN  2020-04-07 18:01:58.344046
# 570   2020-04-04 00:39:19.370721         NaN  2020-04-07 18:03:13.106140
# 571   2020-04-04 00:39:46.713419         NaN  2020-04-07 18:04:47.208681
# 581   2020-04-04 00:49:52.100571         NaN  2020-04-07 18:05:02.854454
# 611   2020-04-04 01:16:35.489190         NaN  2020-04-07 18:03:53.998627
# 617   2020-04-04 01:22:17.848522         NaN  2020-04-07 18:03:47.452955
# 633   2020-04-04 01:37:17.387705         NaN  2020-04-07 18:03:42.646133
# 659   2020-04-04 02:00:47.790253         NaN  2020-04-07 18:01:53.205983
# 747   2020-04-03 21:42:52.706853         NaN                         NaN
# 754   2020-04-03 23:59:10.487816         NaN  2020-04-07 18:04:18.819369
# 3860                         NaN         NaN  2020-04-07 18:02:01.415806
# 4781  2020-04-04 01:11:02.731372         NaN  2020-04-07 18:04:27.175662
#
#      logoUrl price_version                                              point  \
# 106      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 107      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 197      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 261      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 303      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 309      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 324      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 330      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 333      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 334      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 335      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 352      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 394      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 407      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 410      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 422      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 434      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 441      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 448      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 456      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 460      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 512      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 513      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 514      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 515      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 516      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 524      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 525      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 570      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 571      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 581      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 611      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 617      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 633      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 659      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 747      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 754      NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 3860     NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
# 4781     NaN           NaN  {'lon': -47.050991, 'source': 'GOOGLE', 'lat':...
#
#                                                link_url        lon      lat  \
# 106   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 107   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 197   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 261   /imovel/apartamento-4-quartos-parque-prado-bai... -47.050991 -22.9388
# 303   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 309   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 324   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 330   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 333   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 334   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 335   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 352   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 394   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 407   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 410   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 422   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 434   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 441   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 448   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 456   /imovel/apartamento-4-quartos-parque-prado-bai... -47.050991 -22.9388
# 460   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 512   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 513   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 514   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 515   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 516   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 524   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 525   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 570   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 571   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 581   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 611   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 617   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 633   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 659   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 747   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 754   /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 3860  /imovel/apartamento-3-quartos-parque-prado-bai... -47.050991 -22.9388
# 4781  /imovel/apartamento-1-quartos-parque-prado-bai... -47.050991 -22.9388
#
#      dist
# 106   0.0
# 107   0.0
# 197   0.0
# 261   0.0
# 303   0.0
# 309   0.0
# 324   0.0
# 330   0.0
# 333   0.0
# 334   0.0
# 335   0.0
# 352   0.0
# 394   0.0
# 407   0.0
# 410   0.0
# 422   0.0
# 434   0.0
# 441   0.0
# 448   0.0
# 456   0.0
# 460   0.0
# 512   0.0
# 513   0.0
# 514   0.0
# 515   0.0
# 516   0.0
# 524   0.0
# 525   0.0
# 570   0.0
# 571   0.0
# 581   0.0
# 611   0.0
# 617   0.0
# 633   0.0
# 659   0.0
# 747   0.0
# 754   0.0
# 3860  0.0
# 4781  0.0
#
# [39 rows x 56 columns]

# %%
df1i = pd.DataFrame()

for index, row in df1.iterrows():
    arr1 = []
    for m in row['medias']:
        file_name = IMGFOLDER + m['new_url']
        img = PIL.Image.open(file_name)
        img_hash = imagehash.average_hash(img)
        arr1.append(img_hash)
        
    df1i = df1i.append(pd.DataFrame({'id_vivareal': row['id_vivareal'], 'img': arr1}))

df1i
# Out:
#    id_vivareal               img
# 0   2462027022  0303c387f7f3470f
# 1   2462027022  5f9f5b0303901014
# 2   2462027022  007070e0fc7e7c20
# 3   2462027022  1f1f1f1301406070
# 4   2462027022  0c0ee7321a08707d
# 5   2462027022  ffef02000028f06c
# 6   2462027022  607c7c6c60e0e0c0
# 7   2462027022  8bc3838383838383
# 8   2462027022  d8c1c058fcf8f8f8
# 9   2462027022  313171d19f7f3f3f
# 10  2462027022  0f2ffbffe0d90101
# 11  2462027022  ffff7f0000000100
# 12  2462027022  ffffff0000000100
# 13  2462027022  7c7c7c7870777776
# 14  2462027022  fffffbe3eddc4000
# 15  2462027022  60a0e0d09f3f3fdf
# 16  2462027022  ffef02000020f07c
# 17  2462027022  0c0ee7321a18707d
# 18  2462027022  808090b333337333
# 19  2462027022  cfcf1f1e0e2c3807
# 20  2462027022  fefc7c0747672760
# 21  2462027022  8b83038181818181
# 22  2462027022  0000083cfcfcfcfc
# 23  2462027022  ccceccc84cccf078
# 24  2462027022  1e1c1e9ea0e08c8f
# 25  2462027022  f7f7e7c702000048
# 26  2462027022  cecf0f0e7cfc4000
# 27  2462027022  1c04b01c8f7f6606
# 28  2462027022  08c8f87818ddddfd

# %%
df2i = pd.DataFrame()

for index, row in df2.iterrows():
    arr1 = []
    for m in row['medias']:
        file_name = IMGFOLDER + m['new_url']
        img = PIL.Image.open(file_name)
        img_hash = imagehash.average_hash(img)
        arr1.append(img_hash)
        
    df2i = df1i.append(pd.DataFrame({'id_vivareal': row['id_vivareal'], 'img': arr1}))

df2i
# Out:
#    id_vivareal               img
# 0   2462027022  0303c387f7f3470f
# 1   2462027022  5f9f5b0303901014
# 2   2462027022  007070e0fc7e7c20
# 3   2462027022  1f1f1f1301406070
# 4   2462027022  0c0ee7321a08707d
# 5   2462027022  ffef02000028f06c
# 6   2462027022  607c7c6c60e0e0c0
# 7   2462027022  8bc3838383838383
# 8   2462027022  d8c1c058fcf8f8f8
# 9   2462027022  313171d19f7f3f3f
# 10  2462027022  0f2ffbffe0d90101
# 11  2462027022  ffff7f0000000100
# 12  2462027022  ffffff0000000100
# 13  2462027022  7c7c7c7870777776
# 14  2462027022  fffffbe3eddc4000
# 15  2462027022  60a0e0d09f3f3fdf
# 16  2462027022  ffef02000020f07c
# 17  2462027022  0c0ee7321a18707d
# 18  2462027022  808090b333337333
# 19  2462027022  cfcf1f1e0e2c3807
# 20  2462027022  fefc7c0747672760
# 21  2462027022  8b83038181818181
# 22  2462027022  0000083cfcfcfcfc
# 23  2462027022  ccceccc84cccf078
# 24  2462027022  1e1c1e9ea0e08c8f
# 25  2462027022  f7f7e7c702000048
# 26  2462027022  cecf0f0e7cfc4000
# 27  2462027022  1c04b01c8f7f6606
# 28  2462027022  08c8f87818ddddfd
# 0     75007517  7f0000f0f8f8f8e0
# 1     75007517  ffffcbdb73030101
# 2     75007517  7f1f070f07072602
# 3     75007517  7ffd81c0e0787060
# 4     75007517  1f27273f3f332038
# 5     75007517  0763f7fbc3030300
# 6     75007517  0f0f1f1f1f1f181c
# 7     75007517  7f7f07030f070303
# 8     75007517  f0f0e0e1f0000100
# 9     75007517  203bb3f3e3f3f000
# 10    75007517  0c043cfcfcfcf031
# 11    75007517  ffef79c9c9c10010
# 12    75007517  0c040c0d0d0c3c3c
# 13    75007517  000060707078f8f8
# 14    75007517  030f0f0f0f9b1313
# 15    75007517  0e000b1f1f1f0800
# 16    75007517  70606060707c7e7e
# 17    75007517  c0c0c1c1c0c0c0c0
# 18    75007517  ff7fd0c0c0c08f07
# 19    75007517  c8c8ffffc30020b0
# 20    75007517  3f0f078c0f060707
# 21    75007517  f8d8d8d8d8c880e0

# %%
# Out:
# 51

# %%
import requests
import shutil
import os
import datetime
import PIL
import imagehash
from os import listdir
from os.path import isfile, join

# %%
CUTOFF = 5

IMGFOLDER = '/home/dzanardo/github/apartamento/images_remote/'
arr1 = []
arr2 = []

for index, row in df1.iterrows():
    count_similar = 0
    for m in row['medias']:
        file_name = IMGFOLDER + m['new_url']
        img = PIL.Image.open(file_name)
        img_hash = imagehash.average_hash(img)
        arr1.append(img_hash)
        
for index2, row2 in df2.iterrows():
    for m2 in row2['medias']:
        file_name2 = IMGFOLDER + m2['new_url']
        img2 = PIL.Image.open(file_name2)
        img_hash2 = imagehash.average_hash(img2)
        arr2.append(img_hash2)

# %%
for ar1 in arr1:
    for ar2 in arr2:
        a = ar1 - ar2 < CUTOFF
