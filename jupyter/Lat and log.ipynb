# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
import json

# %%
# Out:
# diego

# %%
json_file_path = "data/data.txt"

with open(json_file_path, encoding='utf-8', errors='ignore') as j:
     d = json.loads(j.read())
df = pd.DataFrame(d)
df.head()
# Out:
#                         _id displayAddressType  \
# 0  5e876ba21d41c80d93f083c7       NEIGHBORHOOD
# 1  5e876ba51d41c80d93f083c8       NEIGHBORHOOD
# 2  5e876ba51d41c80d93f083c9       NEIGHBORHOOD
# 3  5e876ba51d41c80d93f083ca                ALL
# 4  5e876ba51d41c80d93f083cc       NEIGHBORHOOD
#
#                                            amenities   feedsId contractType  \
# 0  AIR_CONDITIONING; BARBECUE_GRILL; KITCHEN; ELE...    AP1174  REAL_ESTATE
# 1         BALCONY; BARBECUE_GRILL; GOURMET_BALCONY;   AP249880  REAL_ESTATE
# 2         BALCONY; BARBECUE_GRILL; GOURMET_BALCONY;   AP249880  REAL_ESTATE
# 3  BALCONY; BARBECUE_GRILL; FURNISHED; GOURMET_BA...  AP013420  REAL_ESTATE
# 4  AIR_CONDITIONING; BARBECUE_GRILL; KITCHEN; ELE...    AP6103  REAL_ESTATE
#
#   usableAreas       constructionStatus videoTourLink listingType  \
# 0       127;   ConstructionStatus_NONE                      USED
# 1       162;   ConstructionStatus_NONE                      USED
# ...

# %%
df1 = df[["title", "createdAt", "updatedAt", "address__point__lon", "address__point__lat", "address__zipCode", "address__level", "address__neighborhood", "price", "id_vivareal"]]

df1.head()
# Out:
#                                                title  \
# 0  Apartamento residencial à venda, Parque Prado,...
# 1              apartamento - Parque Prado - Campinas
# 2              apartamento - Parque Prado - Campinas
# 3              apartamento - Parque Prado - Campinas
# 4  Apartamento residencial à venda, Parque Prado,...
#
#                   createdAt                 updatedAt  address__point__lon  \
# 0  2018-11-20T00:14:15.594Z  2020-04-02T22:30:45.851Z           -47.049274
# 1  2020-01-04T03:46:07.081Z  2020-04-03T05:59:28.994Z           -47.049899
# 2  2020-03-04T09:42:25.715Z  2020-04-02T17:29:40.421Z           -47.049899
# 3  2020-03-05T10:10:36.853Z  2020-04-03T08:03:54.124Z           -47.049510
# 4  2019-12-13T08:17:03.867Z  2020-04-02T17:34:06.233Z           -47.049274
#
#    address__point__lat address__zipCode address__level address__neighborhood  \
# 0           -22.942955         13044163         STREET          Parque Prado
# ...

# %%
import numpy as np
def haversine_np(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    

    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

# %%
haversine_np(-22.93886, -47.050842, -22.9388, -47.050991)
# Out:
# 0.017169548252975595

# %%
haversine_np(-22.8825, -47.0474, -22.9388, -47.050991)
# Out:
# 4.281522768072774

# %%
df['dist'] = \
    haversine_np(-22.942955, -47.049274, df1.address__point__lat.shift(), df1.address__point__lon.shift())

df[['dist', "title", "createdAt", "updatedAt", "address__point__lon", "address__point__lat", "address__zipCode", "address__level", "address__neighborhood", "price", "id_vivareal"]]
# Out:
#           dist                                              title  \
# 0          NaN  Apartamento residencial à venda, Parque Prado,...
# 1     0.000000              apartamento - Parque Prado - Campinas
# 2     0.139250              apartamento - Parque Prado - Campinas
# 3     0.139250              apartamento - Parque Prado - Campinas
# 4     0.050891  Apartamento residencial à venda, Parque Prado,...
# ...        ...                                                ...
# 5049  0.188048  Apartamento para venda no Parque Prado em Camp...
# 5050  0.188048              apartamento - Parque Prado - Campinas
# 5051  0.256304  Apartamento residencial à venda, Jardim Amazon...
# 5052  1.053942  Incrível apartamento de dois quartos, 60m, no ...
# 5053  4.616874         Parque Prado - lindo apartamento - permuta
#
#                      createdAt                 updatedAt  address__point__lon  \
# 0     2018-11-20T00:14:15.594Z  2020-04-02T22:30:45.851Z           -47.049274
# ...

# %%
df['match'] = df.address__point__lat == df.address__point__lon.shift()
